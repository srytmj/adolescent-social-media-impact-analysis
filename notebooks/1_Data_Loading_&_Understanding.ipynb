# %% [markdown]
# ## Tujuan
#
# Tahap ini bertujuan untuk memuat dataset ke dalam lingkungan Python serta memahami struktur dan karakteristik data. Proses ini mencakup identifikasi tipe data, jumlah data, serta pengecekan awal terhadap missing value dan anomali.

# %%
import pandas as pd
import numpy as np

# %%
data = "../data/teen_mental_health.csv"

df = pd.read_csv(data)
df.head()
# Out:
#    age  gender  daily_social_media_hours platform_usage  sleep_hours  \
# 0   14    male                       7.9       Facebook          7.4
# 1   19  female                       1.9         TikTok          8.0
# 2   17  female                       1.3      Instagram          7.6
# 3   15    male                       7.4        YouTube          6.9
# 4   15  female                       4.7  All Platforms          4.9
#
#    screen_time_before_sleep  academic_performance  physical_activity  \
# 0                       2.9                  3.01                1.5
# 1                       2.9                  3.22                0.8
# 2                       0.5                  3.92                0.0
# 3                       1.6                  3.48                0.8
# 4                       3.0                  2.37                1.4
#
#   social_interaction_level  stress_level  anxiety_level  addiction_level  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       1200 non-null   int64
#  1   gender                    1200 non-null   object
#  2   daily_social_media_hours  1200 non-null   float64
#  3   platform_usage            1200 non-null   object
#  4   sleep_hours               1200 non-null   float64
#  5   screen_time_before_sleep  1200 non-null   float64
#  6   academic_performance      1200 non-null   float64
#  7   physical_activity         1200 non-null   float64
#  8   social_interaction_level  1200 non-null   object
#  9   stress_level              1200 non-null   int64
#  10  anxiety_level             1200 non-null   int64
#  11  addiction_level           1200 non-null   int64
#  12  depression_label          1200 non-null   int64
# ...

# %% [markdown]
# Dari informasi di atas, dapat diketahui jumlah baris dan kolom dalam dataset, tipe data masing-masing variabel, serta indikasi awal adanya missing value.

# %%
df.describe()
# Out:
#                age  daily_social_media_hours  sleep_hours  \
# count  1200.000000               1200.000000  1200.000000
# mean     15.928333                  4.536667     6.449417
# std       2.021947                  2.029599     1.442677
# min      13.000000                  1.000000     4.000000
# 25%      14.000000                  2.800000     5.200000
# 50%      16.000000                  4.500000     6.500000
# 75%      18.000000                  6.300000     7.600000
# max      19.000000                  8.000000     9.000000
#
#        screen_time_before_sleep  academic_performance  physical_activity  \
# count               1200.000000           1200.000000        1200.000000
# mean                   1.740333              2.990383           1.014500
# std                    0.716660              0.576758           0.582185
# min                    0.500000              2.000000           0.000000
# 25%                    1.100000              2.500000           0.500000
# ...

# %% [markdown]
# Statistik deskriptif digunakan untuk melihat ringkasan data numerik seperti nilai rata-rata, minimum, maksimum, dan standar deviasi.

# %%
df.isnull().sum()
# Out:
# age                         0
# gender                      0
# daily_social_media_hours    0
# platform_usage              0
# sleep_hours                 0
# screen_time_before_sleep    0
# academic_performance        0
# physical_activity           0
# social_interaction_level    0
# stress_level                0
# anxiety_level               0
# addiction_level             0
# depression_label            0
# mental_health_risk_score    0
# sleep_quality               0
# digital_wellbeing_flag      0
# dtype: int64

# %% [markdown]
# Pengecekan missing value dilakukan untuk mengetahui apakah terdapat data yang tidak lengkap pada setiap atribut.

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['age', 'gender', 'daily_social_media_hours', 'platform_usage',
#        'sleep_hours', 'screen_time_before_sleep', 'academic_performance',
#        'physical_activity', 'social_interaction_level', 'stress_level',
#        'anxiety_level', 'addiction_level', 'depression_label',
#        'mental_health_risk_score', 'sleep_quality', 'digital_wellbeing_flag'],
#       dtype='object')

# %% [markdown]
# ## Kesimpulan Awal
#
# Berdasarkan hasil eksplorasi awal, dataset memiliki sejumlah atribut yang mencakup demografi remaja, perilaku penggunaan media sosial dan gaya hidup (seperti durasi screen time dan jam tidur), serta indikator kesehatan mental (seperti tingkat stres, kecemasan, dan kesejahteraan digital).
#
# Beberapa variabel masih perlu diproses lebih lanjut, seperti penanganan missing value (jika ada), transformasi tipe data, serta pembuatan fitur baru agar dapat digunakan secara optimal pada tahap analisis dan pemodelan berikutnya.
